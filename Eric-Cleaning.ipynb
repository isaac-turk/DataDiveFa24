# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
roster = pd.read_csv('2023-2024/23-24-Roster.csv')
roster_pg = pd.read_csv('2023-2024/23-24-PerGame.csv')
to_pg = pd.read_csv('2023-2024/23-24-PerGameTeam&OpponentStats.csv')
results = pd.read_csv('2023-2024/23-24-ScheduleAndResults.csv')
log = pd.read_csv('2023-2024/23-24-BasicGameLog.csv')

# %%
roster
# Out:
#     Unnamed: 0             Player   # Class Pos Height  Weight  \
# 0            0   Terrence Shannon   0    SR   G    6-6   210.0
# 1            1      Marcus Domask   3    SR   F    6-6   215.0
# 2            2    Coleman Hawkins  33    SR   F   6-10   200.0
# 3            3    Quincy Guerrier  13    SR   F    6-7   220.0
# 4            4         Ty Rodgers  20    SO   G    6-6   200.0
# 5            5        Dain Dainja  42    JR   F    6-9   270.0
# 6            6         Luke Goode  10    JR   G    6-7   200.0
# 7            7      Justin Harmon   4    SR   G    6-4   180.0
# 8            8  Dra Gibbs-Lawhorn   2    FR   G    6-1   185.0
# 9            9    Amani Hansberry  35    FR   F    6-8   240.0
# 10          10    Niccolo Moretti  11    FR   G    6-1   170.0
# 11          11            AJ Redd   5    SO   G    6-3   170.0
# 12          12       Max Williams  25    JR   G    6-2   190.0
# 13          13     Sencire Harris   1    SO   G    6-4     NaN
# ...

# %%
roster = roster.drop(columns='Unnamed: 0')
roster
# Out:
#                Player   # Class Pos Height  Weight           Hometown  \
# 0    Terrence Shannon   0    SR   G    6-6   210.0        Chicago, IL
# 1       Marcus Domask   3    SR   F    6-6   215.0         Waupun, WI
# 2     Coleman Hawkins  33    SR   F   6-10   200.0     Sacramento, CA
# 3     Quincy Guerrier  13    SR   F    6-7   220.0   Montreal, Canada
# 4          Ty Rodgers  20    SO   G    6-6   200.0        Saginaw, MI
# 5         Dain Dainja  42    JR   F    6-9   270.0  Brooklyn Park, MN
# 6          Luke Goode  10    JR   G    6-7   200.0     Fort Wayne, IN
# 7       Justin Harmon   4    SR   G    6-4   180.0        Chicago, IL
# 8   Dra Gibbs-Lawhorn   2    FR   G    6-1   185.0      Lafayette, IN
# 9     Amani Hansberry  35    FR   F    6-8   240.0      Baltimore, MD
# 10    Niccolo Moretti  11    FR   G    6-1   170.0     Bologna, Italy
# 11            AJ Redd   5    SO   G    6-3   170.0        Chicago, IL
# ...

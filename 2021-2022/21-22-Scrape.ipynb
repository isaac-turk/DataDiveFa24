# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.sports-reference.com/cbb/schools/illinois/men/2022.html'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" data-root="/home/cbb/build" data-version="klecko-" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
# <link href="https://cdn.ssref.net/req/202409131" rel="dns-prefetch"/>
# <script>
# /* https://docs.osano.com/hc/en-us/articles/22469433444372-Google-Consent-Mode-v2  */
#   window.dataLayer = window.dataLayer ||[];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('consent','default',{
#         'ad_storage':'denied',
#         'analytics_storage':'denied',
#         'ad_user_data':'denied',
#         'ad_personalization':'denied',
#         'personalization_storage':'denied',
#         'functionality_storage':'granted',
#         'security_storage':'granted',
#         'wait_for_update': 500
#       });
#       gtag("set", "ads_data_redaction", true);
# </script>
# ...

# %%
roster_table = soup.find('table', id = 'roster')
print(roster_table)
# Out:
# <table class="sortable stats_table" data-cols-to-freeze=",1" id="roster">
# <caption>Roster Table</caption>
# <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup>
# <thead>
# <tr>
# <th aria-label="Player" class="poptip sort_default_asc center" data-stat="player" scope="col">Player</th>
# <th aria-label="#" class="poptip sort_default_asc center" data-stat="number" scope="col">#</th>
# <th aria-label="Class" class="poptip sort_default_asc center" data-stat="class" scope="col">Class</th>
# <th aria-label="Pos" class="poptip center" data-stat="pos" data-tip="Position" scope="col">Pos</th>
# <th aria-label="Height" class="poptip sort_default_asc center" data-stat="height" data-tip="Height" scope="col">Height</th>
# <th aria-label="Weight" class="poptip sort_default_asc center" data-stat="weight" data-tip="Weight" scope="col">Weight</th>
# <th aria-label="Hometown" class="poptip sort_default_asc center" data-stat="hometown" scope="col">Hometown</th>
# ...

# %%
roster_elements = roster_table.find_all('th', scope = 'col')
print(roster_elements)
# Out:
# [<th aria-label="Player" class="poptip sort_default_asc center" data-stat="player" scope="col">Player</th>, <th aria-label="#" class="poptip sort_default_asc center" data-stat="number" scope="col">#</th>, <th aria-label="Class" class="poptip sort_default_asc center" data-stat="class" scope="col">Class</th>, <th aria-label="Pos" class="poptip center" data-stat="pos" data-tip="Position" scope="col">Pos</th>, <th aria-label="Height" class="poptip sort_default_asc center" data-stat="height" data-tip="Height" scope="col">Height</th>, <th aria-label="Weight" class="poptip sort_default_asc center" data-stat="weight" data-tip="Weight" scope="col">Weight</th>, <th aria-label="Hometown" class="poptip sort_default_asc center" data-stat="hometown" scope="col">Hometown</th>, <th aria-label="High School" class="poptip sort_default_asc center" data-stat="high_school" scope="col">High School</th>, <th aria-label="RSCI Top 100" class="poptip center" data-stat="rsci" data-tip="&lt;strong&gt;RSCI Ranki
# ...

# %%
roster_titles = [th.get_text(strip=True) for th in roster_elements]
print(roster_titles)
# Out:
# ['Player', '#', 'Class', 'Pos', 'Height', 'Weight', 'Hometown', 'High School', 'RSCI Top 100', 'Summary']

# %%
df_roster = pd.DataFrame(columns=roster_titles)
df_roster
# Out:
# Empty DataFrame
# Columns: [Player, #, Class, Pos, Height, Weight, Hometown, High School, RSCI Top 100, Summary]
# Index: []

# %%
roster_body = roster_table.find('tbody')
print(roster_body)
# Out:
# <tbody><tr><th class="left" csk="Cockburn,Kofi" data-stat="player" scope="row"><a href="/cbb/players/kofi-cockburn-1.html">Kofi Cockburn</a></th><td class="center" data-stat="number">21</td><td class="center" csk="3" data-stat="class">JR</td><td class="center" data-stat="pos">C</td><td class="center" csk="84.00" data-stat="height">7-0</td><td class="center" csk="285" data-stat="weight">285</td><td class="left" data-stat="hometown">Kingston, Jamaica</td><td class="left" data-stat="high_school">Oak Hill Academy</td><td class="center" data-stat="rsci">43 (<a href="/cbb/awards/rsci-recruit-rankings-2019.html">2019</a>)</td><td class="left" csk="28-585" data-stat="summary"> 20.9 Pts, 10.6 Reb, 0.8 Ast</td></tr>
# ...

# %%
roster_rows = roster_body.find_all('tr')
print(roster_rows)
# Out:
# [<tr><th class="left" csk="Cockburn,Kofi" data-stat="player" scope="row"><a href="/cbb/players/kofi-cockburn-1.html">Kofi Cockburn</a></th><td class="center" data-stat="number">21</td><td class="center" csk="3" data-stat="class">JR</td><td class="center" data-stat="pos">C</td><td class="center" csk="84.00" data-stat="height">7-0</td><td class="center" csk="285" data-stat="weight">285</td><td class="left" data-stat="hometown">Kingston, Jamaica</td><td class="left" data-stat="high_school">Oak Hill Academy</td><td class="center" data-stat="rsci">43 (<a href="/cbb/awards/rsci-recruit-rankings-2019.html">2019</a>)</td><td class="left" csk="28-585" data-stat="summary"> 20.9 Pts, 10.6 Reb, 0.8 Ast</td></tr>, <tr><th class="left" csk="Plummer,Alfonso" data-stat="player" scope="row"><a href="/cbb/players/alfonso-plummer-1.html">Alfonso Plummer</a></th><td class="center" data-stat="number">11</td><td class="center" csk="4" data-stat="class">SR</td><td class="center" data-stat="pos">G</td><td c
# ...

# %%
for row in roster_rows:
    header = row.find_all('th')
    data = row.find_all('td')

    whole_row = [th.get_text(strip=True) for th in header]
    whole_row.extend([td.get_text(strip=True) for td in data])
    print(whole_row)

    df_roster.loc[len(df_roster)] = whole_row
# Out:
# ['Kofi Cockburn', '21', 'JR', 'C', '7-0', '285', 'Kingston, Jamaica', 'Oak Hill Academy', '43 (2019)', '20.9 Pts, 10.6 Reb, 0.8 Ast']
# ['Alfonso Plummer', '11', 'SR', 'G', '6-1', '182', 'Fajardo, Puerto Rico', 'La Luz Juncos (PR)', '', '14.6 Pts, 2.5 Reb, 1.1 Ast']
# ['Trent Frazier', '1', 'SR', 'G', '6-2', '175', 'Wellington, FL', 'Wellington High School', '', '11.6 Pts, 2.8 Reb, 4.1 Ast']
# ['Jacob Grandison', '3', 'SR', 'G', '6-6', '205', 'Oakland, CA', 'Phillips Exeter Academy', '', '9.6 Pts, 3.8 Reb, 2.3 Ast']
# ['Coleman Hawkins', '33', 'SO', 'F', '6-10', '200', 'Sacramento, CA', 'Prolific Prep', '', '5.9 Pts, 4.3 Reb, 1.5 Ast']
# ['Andre Curbelo', '5', 'SO', 'G', '6-1', '175', 'Vega Baja, Puerto Rico', 'Long Island Lutheran HS', '45 (2020)', '7.5 Pts, 3.1 Reb, 3.2 Ast']
# ["Da'Monte Williams", '20', 'SR', 'G', '6-3', '215', 'Peoria, IL', 'Manual HS', '', '3.9 Pts, 5.0 Reb, 2.5 Ast']
# ...

# %%
df_roster
# Out:
#                       Player   # Class Pos Height Weight  \
# 0              Kofi Cockburn  21    JR   C    7-0    285
# 1            Alfonso Plummer  11    SR   G    6-1    182
# 2              Trent Frazier   1    SR   G    6-2    175
# 3            Jacob Grandison   3    SR   G    6-6    205
# 4            Coleman Hawkins  33    SO   F   6-10    200
# 5              Andre Curbelo   5    SO   G    6-1    175
# 6          Da'Monte Williams  20    SR   G    6-3    215
# 7                RJ Melendez  15    FR   G    6-7    205
# 8                 Omar Payne   4    JR   F   6-10    230
# 9                 Luke Goode  10    FR   G    6-7    200
# 10  Benjamin Bosmans-Verdonk  13    JR   F    6-8    235
# 11        Brandin Podziemski   0    FR   G    6-5    200
# 12         Austin Hutcherson  22    SR   G    6-6    180
# 13              Brandon Lieb  12    SO   C    7-0    210
# 14             Connor Serven   2    SO   F    6-9    215
#
# ...

# %%
df_roster.to_csv(r'/Users/isaac/Desktop/personal/datadive24/21-22/21-22-Roster.csv')

# %%
pg_table = soup.find('table', id = 'season-total_per_game')
print(pg_table)
# Out:
# <table class="stats_table sortable" data-cols-to-freeze=",1" id="season-total_per_game"> <caption>Per Game Team and Opponent Stats Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr> <th aria-label=" " class="poptip center" data-stat="entity" scope="col"> </th> <th aria-label="Games" class="poptip center" data-stat="games" data-tip="Games" scope="col">G</th> <th aria-label="Minutes Played Per Game" class="poptip center" data-filter="1" data-name="Minutes Played Per Game" data-stat="mp_per_g" data-tip="Minutes Played Per Game" scope="col">MP</th> <th aria-label="Field Goals Per Game" class="poptip center" data-stat="fg_per_g" data-tip="Field Goals Per Game" scope="col">FG</th> <th aria-label="Field Goal Attempts Per Game" class="poptip center" data-stat="fga_per_g" data-tip="Field Goal Attempts Per Game" scope="col">FGA</th> <th aria-label="Fie
# ...

# %%
pg_elements = pg_table.find_all('th', scope='col')
print(pg_elements)
# Out:
# [<th aria-label=" " class="poptip center" data-stat="entity" scope="col"> </th>, <th aria-label="Games" class="poptip center" data-stat="games" data-tip="Games" scope="col">G</th>, <th aria-label="Minutes Played Per Game" class="poptip center" data-filter="1" data-name="Minutes Played Per Game" data-stat="mp_per_g" data-tip="Minutes Played Per Game" scope="col">MP</th>, <th aria-label="Field Goals Per Game" class="poptip center" data-stat="fg_per_g" data-tip="Field Goals Per Game" scope="col">FG</th>, <th aria-label="Field Goal Attempts Per Game" class="poptip center" data-stat="fga_per_g" data-tip="Field Goal Attempts Per Game" scope="col">FGA</th>, <th aria-label="Field Goal Percentage" class="poptip center" data-filter="1" data-name="Field Goal Percentage" data-stat="fg_pct" data-tip="Field Goal Percentage" scope="col">FG%</th>, <th aria-label="2-Point Field Goals Per Game" class="poptip center" data-stat="fg2_per_g" data-tip="2-Point Field Goals Per Game" scope="col">2P</th>, <th
# ...

# %%
pg_titles = [th.get_text(strip=True) for th in pg_elements]
print(pg_titles)
# Out:
# ['', 'G', 'MP', 'FG', 'FGA', 'FG%', '2P', '2PA', '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']

# %%
df_pg = pd.DataFrame(columns=pg_titles)
df_pg
# Out:
# Empty DataFrame
# Columns: [, G, MP, FG, FGA, FG%, 2P, 2PA, 2P%, 3P, 3PA, 3P%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS]
# Index: []
#
# [0 rows x 24 columns]

# %%
pg_body = pg_table.find('tbody')
print(pg_body)
# Out:
# <tbody> <tr><th class="left" data-stat="entity" scope="row">Team</th><td class="center" data-stat="games">33</td><td class="center" data-stat="mp_per_g">40.3</td><td class="center" data-stat="fg_per_g">26.2</td><td class="center" data-stat="fga_per_g">58.3</td><td class="center" data-stat="fg_pct">.448</td><td class="center" data-stat="fg2_per_g">17.2</td><td class="center" data-stat="fg2a_per_g">33.5</td><td class="center" data-stat="fg2_pct">.514</td><td class="center" data-stat="fg3_per_g">8.9</td><td class="center" data-stat="fg3a_per_g">24.9</td><td class="center" data-stat="fg3_pct">.359</td><td class="center" data-stat="ft_per_g">13.2</td><td class="center" data-stat="fta_per_g">18.7</td><td class="center" data-stat="ft_pct">.706</td><td class="center" data-stat="orb_per_g">11.5</td><td class="center" data-stat="drb_per_g">27.0</td><td class="center" data-stat="trb_per_g">38.5</td><td class="center" data-stat="ast_per_g">15.2</td><td class="center" data-stat="stl_per_g">5.2</t
# ...

# %%
pg_rows = pg_body.find_all('tr')
print(pg_rows)
# Out:
# [<tr><th class="left" data-stat="entity" scope="row">Team</th><td class="center" data-stat="games">33</td><td class="center" data-stat="mp_per_g">40.3</td><td class="center" data-stat="fg_per_g">26.2</td><td class="center" data-stat="fga_per_g">58.3</td><td class="center" data-stat="fg_pct">.448</td><td class="center" data-stat="fg2_per_g">17.2</td><td class="center" data-stat="fg2a_per_g">33.5</td><td class="center" data-stat="fg2_pct">.514</td><td class="center" data-stat="fg3_per_g">8.9</td><td class="center" data-stat="fg3a_per_g">24.9</td><td class="center" data-stat="fg3_pct">.359</td><td class="center" data-stat="ft_per_g">13.2</td><td class="center" data-stat="fta_per_g">18.7</td><td class="center" data-stat="ft_pct">.706</td><td class="center" data-stat="orb_per_g">11.5</td><td class="center" data-stat="drb_per_g">27.0</td><td class="center" data-stat="trb_per_g">38.5</td><td class="center" data-stat="ast_per_g">15.2</td><td class="center" data-stat="stl_per_g">5.2</td><td c
# ...

# %%
for row in pg_rows:
    header = row.find_all('th')
    data = row.find_all('td')

    whole_row = [th.get_text(strip=True) for th in header]
    whole_row.extend([td.get_text(strip=True) for td in data])
    print(whole_row)

    df_pg.loc[len(df_pg)] = whole_row
# Out:
# ['Team', '33', '40.3', '26.2', '58.3', '.448', '17.2', '33.5', '.514', '8.9', '24.9', '.359', '13.2', '18.7', '.706', '11.5', '27.0', '38.5', '15.2', '5.2', '3.0', '12.4', '16.3', '74.4']
# ['Rank', '', '', '116th', '149th', '126th', '244th', '267th', '126th', '40th', '66th', '58th', '132nd', '118th', '211th', '61st', '53rd', '35th', '43rd', '311th', '195th', '205th', '204th', '84th']
# ['Opponent', '33', '40.3', '24.7', '59.9', '.413', '19.1', '42.2', '.452', '5.7', '17.7', '.320', '12.1', '16.9', '.715', '9.8', '23.2', '33.0', '10.2', '6.6', '2.9', '10.6', '18.1', '67.2']
# ['Rank', '', '', '171st', '281st', '61st', '279th', '349th', '26th', '23rd', '19th', '92nd', '160th', '164th', '175th', '187th', '66th', '96th', '316th', '212th', '127th', '35th', '291st', '119th']

# %%
df_pg
# Out:
#               G    MP     FG    FGA    FG%     2P    2PA    2P%    3P  ...  \
# 0      Team  33  40.3   26.2   58.3   .448   17.2   33.5   .514   8.9  ...
# 1      Rank            116th  149th  126th  244th  267th  126th  40th  ...
# 2  Opponent  33  40.3   24.7   59.9   .413   19.1   42.2   .452   5.7  ...
# 3      Rank            171st  281st   61st  279th  349th   26th  23rd  ...
#
#      FT%    ORB   DRB   TRB    AST    STL    BLK    TOV     PF    PTS
# 0   .706   11.5  27.0  38.5   15.2    5.2    3.0   12.4   16.3   74.4
# 1  211th   61st  53rd  35th   43rd  311th  195th  205th  204th   84th
# 2   .715    9.8  23.2  33.0   10.2    6.6    2.9   10.6   18.1   67.2
# 3  175th  187th  66th  96th  316th  212th  127th   35th  291st  119th
#
# [4 rows x 24 columns]

# %%
df_pg.to_csv(r'/Users/isaac/Desktop/personal/datadive24/21-22/21-22-Team&Opp-Per-Game.csv')

# %%
apg_table = soup.find('table', id='per_game')
print(apg_table)
# Out:
# <table class="stats_table sortable" data-cols-to-freeze=",2" id="per_game"> <caption>Per Game Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr> <th aria-label="Rk" class="ranker poptip sort_default_asc center" data-stat="ranker" data-tip="Rank" scope="col">Rk</th> <th aria-label="Player" class="poptip sort_default_asc center" data-stat="player" scope="col">Player</th> <th aria-label="Games" class="poptip center" data-stat="games" data-tip="Games" scope="col">G</th> <th aria-label="GS" class="poptip center" data-stat="games_started" data-tip="Games Started" scope="col">GS</th> <th aria-label="Minutes Played Per Game" class="poptip center" data-filter="1" data-name="Minutes Played Per Game" data-stat="mp_per_g" data-tip="Minutes Played Per Game" scope="col">MP</th> <th aria-label="Field Goals Per Game" class="poptip center" data-st
# ...

# %%
apg_elements = apg_table.find_all('th', scope='col')
print(apg_elements)
# Out:
# [<th aria-label="Rk" class="ranker poptip sort_default_asc center" data-stat="ranker" data-tip="Rank" scope="col">Rk</th>, <th aria-label="Player" class="poptip sort_default_asc center" data-stat="player" scope="col">Player</th>, <th aria-label="Games" class="poptip center" data-stat="games" data-tip="Games" scope="col">G</th>, <th aria-label="GS" class="poptip center" data-stat="games_started" data-tip="Games Started" scope="col">GS</th>, <th aria-label="Minutes Played Per Game" class="poptip center" data-filter="1" data-name="Minutes Played Per Game" data-stat="mp_per_g" data-tip="Minutes Played Per Game" scope="col">MP</th>, <th aria-label="Field Goals Per Game" class="poptip center" data-stat="fg_per_g" data-tip="Field Goals Per Game" scope="col">FG</th>, <th aria-label="Field Goal Attempts Per Game" class="poptip center" data-stat="fga_per_g" data-tip="Field Goal Attempts Per Game" scope="col">FGA</th>, <th aria-label="Field Goal Percentage" class="poptip center" data-filter="1"
# ...

# %%
apg_titles = [th.get_text(strip=True) for th in apg_elements]
print(apg_titles)
# Out:
# ['Rk', 'Player', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '2P', '2PA', '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']

# %%
df_apg = pd.DataFrame(columns=apg_titles)
df_apg
# Out:
# Empty DataFrame
# Columns: [Rk, Player, G, GS, MP, FG, FGA, FG%, 2P, 2PA, 2P%, 3P, 3PA, 3P%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS]
# Index: []
#
# [0 rows x 26 columns]

# %%
apg_body = apg_table.find('tbody')
print(apg_body)
# Out:
# <tbody> <tr><th class="right" csk="1" data-stat="ranker" scope="row">1</th><td class="left" csk="Cockburn,Kofi" data-append-csv="kofi-cockburn-1" data-stat="player"><a href="/cbb/players/kofi-cockburn-1.html">Kofi Cockburn</a></td><td class="right" data-stat="games">28</td><td class="right" data-stat="games_started">28</td><td class="right" data-stat="mp_per_g">30.7</td><td class="right" data-stat="fg_per_g">8.1</td><td class="right" data-stat="fga_per_g">13.6</td><td class="right" data-stat="fg_pct">.593</td><td class="right" data-stat="fg2_per_g">8.1</td><td class="right" data-stat="fg2a_per_g">13.6</td><td class="right" data-stat="fg2_pct">.593</td><td class="right iz" data-stat="fg3_per_g">0.0</td><td class="right iz" data-stat="fg3a_per_g">0.0</td><td class="right iz" data-stat="fg3_pct"></td><td class="right" data-stat="ft_per_g">4.8</td><td class="right" data-stat="fta_per_g">7.3</td><td class="right" data-stat="ft_pct">.655</td><td class="right" data-stat="orb_per_g">3.4</td>
# ...

# %%
apg_rows = apg_body.find_all('tr')
print(apg_rows)
# Out:
# [<tr><th class="right" csk="1" data-stat="ranker" scope="row">1</th><td class="left" csk="Cockburn,Kofi" data-append-csv="kofi-cockburn-1" data-stat="player"><a href="/cbb/players/kofi-cockburn-1.html">Kofi Cockburn</a></td><td class="right" data-stat="games">28</td><td class="right" data-stat="games_started">28</td><td class="right" data-stat="mp_per_g">30.7</td><td class="right" data-stat="fg_per_g">8.1</td><td class="right" data-stat="fga_per_g">13.6</td><td class="right" data-stat="fg_pct">.593</td><td class="right" data-stat="fg2_per_g">8.1</td><td class="right" data-stat="fg2a_per_g">13.6</td><td class="right" data-stat="fg2_pct">.593</td><td class="right iz" data-stat="fg3_per_g">0.0</td><td class="right iz" data-stat="fg3a_per_g">0.0</td><td class="right iz" data-stat="fg3_pct"></td><td class="right" data-stat="ft_per_g">4.8</td><td class="right" data-stat="fta_per_g">7.3</td><td class="right" data-stat="ft_pct">.655</td><td class="right" data-stat="orb_per_g">3.4</td><td cla
# ...

# %%
for row in apg_rows:
    header = row.find_all('th')
    data = row.find_all('td')

    whole_row = [th.get_text(strip=True) for th in header]
    whole_row.extend([td.get_text(strip=True) for td in data])
    print(whole_row)

    df_apg.loc[len(df_apg)] = whole_row
# Out:
# ['1', 'Kofi Cockburn', '28', '28', '30.7', '8.1', '13.6', '.593', '8.1', '13.6', '.593', '0.0', '0.0', '', '4.8', '7.3', '.655', '3.4', '7.2', '10.6', '0.8', '0.8', '1.0', '2.3', '2.4', '20.9']
# ['2', 'Alfonso Plummer', '33', '29', '30.2', '4.7', '11.0', '.424', '1.7', '3.7', '.455', '3.0', '7.3', '.408', '2.3', '2.6', '.874', '0.3', '2.1', '2.5', '1.1', '0.3', '0.0', '1.3', '1.6', '14.6']
# ['3', 'Trent Frazier', '31', '30', '34.7', '3.9', '9.8', '.397', '1.9', '3.6', '.513', '2.0', '6.2', '.328', '1.8', '2.1', '.833', '0.5', '2.3', '2.8', '4.1', '1.3', '0.1', '1.8', '2.0', '11.6']
# ['4', 'Jacob Grandison', '30', '23', '25.0', '3.4', '7.5', '.455', '1.6', '3.0', '.522', '1.8', '4.5', '.410', '0.9', '1.1', '.824', '1.1', '2.7', '3.8', '2.3', '0.3', '0.2', '1.2', '1.7', '9.6']
# ['5', 'Andre Curbelo', '19', '4', '19.3', '2.6', '7.8', '.329', '2.3', '6.1', '.374', '0.3', '1.8', '.176', '2.0', '2.7', '.745', '0.6', '2.5', '3.1', '3.2', '0.7', '0.1', '2.8', '2.3', '7.5']
# ...

# %%
df_apg
# Out:
#     Rk                    Player   G  GS    MP   FG   FGA   FG%   2P   2PA  \
# 0    1             Kofi Cockburn  28  28  30.7  8.1  13.6  .593  8.1  13.6
# 1    2           Alfonso Plummer  33  29  30.2  4.7  11.0  .424  1.7   3.7
# 2    3             Trent Frazier  31  30  34.7  3.9   9.8  .397  1.9   3.6
# 3    4           Jacob Grandison  30  23  25.0  3.4   7.5  .455  1.6   3.0
# 4    5             Andre Curbelo  19   4  19.3  2.6   7.8  .329  2.3   6.1
# 5    6           Coleman Hawkins  33  14  19.0  2.1   4.7  .442  1.5   2.7
# 6    7         Da'Monte Williams  33  30  28.8  1.3   4.2  .307  0.5   1.8
# 7    8               RJ Melendez  22   1   8.5  1.3   2.3  .569  0.9   1.6
# 8    9         Austin Hutcherson   4   1  15.3  0.8   2.0  .375  0.8   1.0
# 9   10                Luke Goode  28   0   8.9  0.6   2.0  .327  0.1   0.4
# 10  11                Omar Payne  32   3   7.4  0.7   1.1  .618  0.7   1.1
# ...

# %%
df_apg.to_csv(r'/Users/isaac/Desktop/personal/datadive24/21-22/21-22-Roster-Per-Game.csv')

# %%
url2 = 'https://www.sports-reference.com/cbb/schools/illinois/men/2022-schedule.html'
page2 = requests.get(url2)
soup2 = BeautifulSoup(page2.text, 'html')
print(soup2)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" data-root="/home/cbb/build" data-version="klecko-" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
# <link href="https://cdn.ssref.net/req/202409131" rel="dns-prefetch"/>
# <script>
# /* https://docs.osano.com/hc/en-us/articles/22469433444372-Google-Consent-Mode-v2  */
#   window.dataLayer = window.dataLayer ||[];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('consent','default',{
#         'ad_storage':'denied',
#         'analytics_storage':'denied',
#         'ad_user_data':'denied',
#         'ad_personalization':'denied',
#         'personalization_storage':'denied',
#         'functionality_storage':'granted',
#         'security_storage':'granted',
#         'wait_for_update': 500
#       });
#       gtag("set", "ads_data_redaction", true);
# </script>
# ...

# %%
sched_table = soup2.find('table', id='schedule')

sched_elements = sched_table.find_all('th', scope='col')
sched_titles = [th.get_text(strip=True) for th in sched_elements]
df_sched = pd.DataFrame(columns=sched_titles)

sched_body = sched_table.find('tbody')
sched_rows = sched_body.find_all('tr')
for row in sched_rows:
    if 'thead' in row.get('class', []):
        continue

    header = row.find_all('th')
    data = row.find_all('td')

    whole_row = [th.get_text(strip = True) for th in header]
    whole_row.extend([td.get_text(strip = True) for td in data])
    print(whole_row)
        
    df_sched.loc[len(df_sched)] = whole_row
# Out:
# ['1', 'Tue, Nov 9, 2021', '8:00p', 'REG', '', 'Jackson State', 'SWAC', '-10.10', 'W', '71', '47', '', '1', '0', 'W 1', 'State Farm Center']
# ['2', 'Fri, Nov 12, 2021', '9:00p', 'REG', '', 'Arkansas State', 'Sun Belt', '-3.27', 'W', '92', '53', '', '2', '0', 'W 2', 'State Farm Center']
# ['3', 'Mon, Nov 15, 2021', '7:00p', 'REG', '@', 'Marquette', 'Big East', '11.36', 'L', '66', '67', '', '2', '1', 'L 1', 'Fiserv Forum']
# ['4', 'Mon, Nov 22, 2021', '6:30p', 'REG', 'N', 'Cincinnati', 'AAC', '7.44', 'L', '51', '71', '', '2', '2', 'L 2', 'T-Mobile Center']
# ['5', 'Tue, Nov 23, 2021', '7:00p', 'REG', 'N', 'Kansas State', 'Big 12', '10.61', 'W', '72', '64', '', '3', '2', 'W 1', 'T-Mobile Center']
# ['6', 'Fri, Nov 26, 2021', '8:00p', 'REG', '', 'Texas-Rio Grande Valley', 'WAC', '-10.18', 'W', '94', '85', '', '4', '2', 'W 2', 'State Farm Center']
# ['7', 'Mon, Nov 29, 2021', '9:00p', 'REG', '', 'Notre Dame', 'ACC', '11.87', 'W', '82', '72', '', '5', '2', 'W 3', 'State Farm Center']
# ...

# %%
df_sched
# Out:
#      G               Date    Time    Type                    Opponent  \
# 0    1   Tue, Nov 9, 2021   8:00p     REG               Jackson State
# 1    2  Fri, Nov 12, 2021   9:00p     REG              Arkansas State
# 2    3  Mon, Nov 15, 2021   7:00p     REG  @                Marquette
# 3    4  Mon, Nov 22, 2021   6:30p     REG  N               Cincinnati
# 4    5  Tue, Nov 23, 2021   7:00p     REG  N             Kansas State
# 5    6  Fri, Nov 26, 2021   8:00p     REG     Texas-Rio Grande Valley
# 6    7  Mon, Nov 29, 2021   9:00p     REG                  Notre Dame
# 7    8   Fri, Dec 3, 2021   7:00p     REG                     Rutgers
# 8    9   Mon, Dec 6, 2021   7:00p     REG  @                     Iowa
# 9   10  Sat, Dec 11, 2021   5:00p     REG                 Arizona(11)
# 10  11  Sat, Dec 18, 2021   1:00p     REG          Saint Francis (PA)
# 11  12  Wed, Dec 22, 2021   9:00p     REG  N                 Missouri
# ...

# %%
df_sched
# Out:
#      G               Date    Time    Type                    Opponent  \
# 0    1   Tue, Nov 9, 2021   8:00p     REG               Jackson State
# 1    2  Fri, Nov 12, 2021   9:00p     REG              Arkansas State
# 2    3  Mon, Nov 15, 2021   7:00p     REG  @                Marquette
# 3    4  Mon, Nov 22, 2021   6:30p     REG  N               Cincinnati
# 4    5  Tue, Nov 23, 2021   7:00p     REG  N             Kansas State
# 5    6  Fri, Nov 26, 2021   8:00p     REG     Texas-Rio Grande Valley
# 6    7  Mon, Nov 29, 2021   9:00p     REG                  Notre Dame
# 7    8   Fri, Dec 3, 2021   7:00p     REG                     Rutgers
# 8    9   Mon, Dec 6, 2021   7:00p     REG  @                     Iowa
# 9   10  Sat, Dec 11, 2021   5:00p     REG                 Arizona(11)
# 10  11  Sat, Dec 18, 2021   1:00p     REG          Saint Francis (PA)
# 11  12  Wed, Dec 22, 2021   9:00p     REG  N                 Missouri
# ...

# %%
df_sched.to_csv(r'/Users/isaac/Desktop/personal/datadive24/21-22/21-22-Sched&Results.csv')

# %%
url3 = 'https://www.sports-reference.com/cbb/schools/illinois/men/2022-gamelogs.html'
page3 = requests.get(url3)
soup3 = BeautifulSoup(page3.text, 'html')
print(soup3)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" data-root="/home/cbb/build" data-version="klecko-" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
# <link href="https://cdn.ssref.net/req/202409131" rel="dns-prefetch"/>
# <script>
# /* https://docs.osano.com/hc/en-us/articles/22469433444372-Google-Consent-Mode-v2  */
#   window.dataLayer = window.dataLayer ||[];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('consent','default',{
#         'ad_storage':'denied',
#         'analytics_storage':'denied',
#         'ad_user_data':'denied',
#         'ad_personalization':'denied',
#         'personalization_storage':'denied',
#         'functionality_storage':'granted',
#         'security_storage':'granted',
#         'wait_for_update': 500
#       });
#       gtag("set", "ads_data_redaction", true);
# </script>
# ...

# %%
log_table = soup3.find('table', id='sgl-basic_NCAAM')

log_elements = log_table.find_all('th', scope='col')
log_titles = [th.get_text(strip=True) for th in log_elements]
df_log = pd.DataFrame(columns=log_titles)

log_body = log_table.find('tbody')
log_rows = log_body.find_all('tr')
for row in log_rows:
    if 'over_header thead' in row.get('class', []):
        continue
    elif 'thead' in row.get('class', []):
        continue

    header = row.find_all('th')
    data = row.find_all('td')

    whole_row = [th.get_text(strip=True) for th in header]
    whole_row.extend([td.get_text(strip=True) for td in data])
    print(whole_row)

    df_log.loc[len(df_log)] = whole_row
# Out:
# ['1', '2021-11-09', '', 'Jackson State', 'W', '71', '47', '24', '55', '.436', '9', '21', '.429', '14', '21', '.667', '15', '43', '16', '12', '4', '18', '14', '', '19', '51', '.373', '7', '16', '.438', '2', '5', '.400', '5', '24', '7', '11', '4', '19', '22']
# ['2', '2021-11-12', '', 'Arkansas State', 'W', '92', '53', '32', '70', '.457', '5', '25', '.200', '23', '38', '.605', '22', '54', '14', '5', '5', '13', '18', '', '18', '59', '.305', '3', '16', '.188', '14', '16', '.875', '6', '27', '9', '4', '2', '18', '29']
# ['3', '2021-11-15', '@', 'Marquette', 'L', '66', '67', '25', '66', '.379', '9', '24', '.375', '7', '11', '.636', '18', '48', '13', '7', '2', '23', '24', '', '22', '54', '.407', '5', '17', '.294', '18', '31', '.581', '5', '27', '9', '10', '7', '14', '16']
# ...

# %%
df_log
# Out:
#      G        Date                         Opp      W/L   Tm Opp  FG FGA  \
# 0    1  2021-11-09               Jackson State        W   71  47  24  55
# 1    2  2021-11-12              Arkansas State        W   92  53  32  70
# 2    3  2021-11-15  @                Marquette        L   66  67  25  66
# 3    4  2021-11-22  N               Cincinnati        L   51  71  16  57
# 4    5  2021-11-23  N             Kansas State        W   72  64  25  48
# 5    6  2021-11-26     Texas-Rio Grande Valley        W   94  85  33  53
# 6    7  2021-11-29                  Notre Dame        W   82  72  28  53
# 7    8  2021-12-03                     Rutgers        W   86  51  32  66
# 8    9  2021-12-06  @                     Iowa        W   87  83  26  59
# 9   10  2021-12-11                     Arizona        L   79  83  27  68
# 10  11  2021-12-18          Saint Francis (PA)        W  106  48  38  58
# 11  12  2021-12-22  N                 Missouri        W   88  63  33  58
# ...

# %%
df_log.to_csv(r'/Users/isaac/Desktop/personal/datadive24/21-22/21-22-Game-Log.csv')
